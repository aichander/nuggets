# %% [markdown]
# # 2025-02-24: Alluvial Plot Input
# #### By [Aishwarya Chander](aishwarya.chander@alleninstitute.org), High Resolution Translational Immunology, Allen Institute for Immunology
#
# **Main aim**: Compute frequencies of cells and log normalize them based on a condition to use as input for the aaluvial plot.

# %%
import pandas as pd
import numpy as np

# %%
def calculate_frequencies(ndmm_meta, categories, output_file):
    # Filter the DataFrame based on the given categories and treatment
    filtered_df = ndmm_meta[
        ndmm_meta['manual.label_l3'].isin(categories) & 
        (ndmm_meta['manual.treatment_dara'] == 'non_dara')
    ]

    # Select relevant columns
    data = filtered_df[['manual.label_l3', 'sample.visitDetails']]

    # Calculate frequency data
    # Here, adjust to match the name of your metadata field
    frequency_data = data.groupby(['sample.visitDetails', 'manual.label_l3']).size().reset_index(name='count')
    total_counts = data.groupby('sample.visitDetails').size().reset_index(name='total_count')
    frequency_data = frequency_data.merge(total_counts, on='sample.visitDetails')
    frequency_data['frequency'] = frequency_data['count'] / frequency_data['total_count']

    # Normalize frequencies
    frequency_data['normalized_frequency'] = frequency_data.groupby('manual.label_l3')['frequency'].transform(lambda x: x / x.sum())

    # Apply log transformation
    frequency_data['log_normalized_frequency'] = np.log1p(frequency_data['normalized_frequency'])

    # Save to CSV
    frequency_data.to_csv(output_file, index=False)

# %%
## This is your adata.obs or any table with the counts of labels
ndmm_meta = pd.read_csv('../../certpro-ndmm-data/ndmm-bmmc-csvs_pkls/2025-02-25-ndmm-bmmc-labelled-all-cells-obs-metadata.csv')
# Out:
# /tmp/ipykernel_1744/2908113196.py:2: DtypeWarning: Columns (36,47,48,52,55,56,57,59,60,61,63,64,65,66,67,68,69) have mixed types. Specify dtype option on import or set low_memory=False.
#   ndmm_meta = pd.read_csv('../../certpro-ndmm-data/ndmm-bmmc-csvs_pkls/2025-02-25-ndmm-bmmc-labelled-all-cells-obs-metadata.csv')

# %%
## Check to select the cell types you need for your analysis.
sorted(ndmm_meta['manual.label_l3'].unique())
# Out:
# ['b_memory_cd95',
#  'b_memory_core',
#  'b_memory_effector',
#  'b_naive',
#  'b_naive_activated',
#  'b_naive_isg_pos',
#  'b_precursor',
#  'b_precursor_igk',
#  'b_precursor_vdj',
#  'b_transitional',
#  'b_transitional_isg_pos',
#  'dc_asdc',
#  'dc_cdc1',
#  'dc_cdc2',
#  'dc_cdc2-cd14.pos',
#  'dc_cdc2-isg.pos',
#  'dc_pdc',
#  'mono_cd14',
#  'mono_cd14_isg_high',
#  'mono_cd16',
#  'mono_intermediate',
#  'msc_fibroblasts',
#  'msc_platelet',
#  'nk_adaptive',
#  'nk_cd56_bright',
#  'nk_cd56_dim-gzmk_neg',
#  'nk_cd56_dim-gzmk_pos',
#  'nk_cd56_dim-isg_pos',
#  'nk_effector',
#  'nk_t_proliferating_nk_like',
#  'nk_t_proliferating_t_like',
#  'nk_tissue_resident',
#  'plasma',
#  'prog_b_proliferating',
#  'prog_clp',
#  'prog_cmp',
#  'prog_cmp_mono',
#  'prog_dc',
#  'prog_dc_cdc',
#  'prog_dc_pdc',
#  'prog_hspc',
#  'prog_hspc_proliferating',
#  'prog_lmpp',
#  'prog_mature_ery',
#  'prog_mature_ery_polychromatic',
#  'prog_mep',
#  'prog_mk',
#  'prog_pre_ery',
#  't_cd4_central_memory',
#  't_cd4_effector_1',
#  't_cd4_effector_2',
#  't_cd4_memory',
#  't_cd4_naive',
#  't_cd4_regs',
#  't_cd8_effector_1',
#  't_cd8_effector_2',
#  't_cd8_memory_tissue_resident',
#  't_cd8_naive',
#  't_dn',
#  't_gd',
#  't_mait']

# %%
## If your hierarchy is perfect, you can use just 1 inout (for example all cell types under L1 B cells)

categories = [
    'b_memory_cd95', 'b_memory_core', 'b_memory_effector', 'b_naive',
    'b_naive_activated', 'b_naive_isg_pos', 'b_transitional',
    'b_transitional_isg_pos', 'prog_b_proliferating',
    'b_precursor_proliferating', 'b_precursor_lcr', 'b_precursor_hcr'
]

calculate_frequencies(ndmm_meta, categories, 'l3_alu_b_cells.csv')

# %%
## Output is a table of frequencies with different normalizations as defined in the function above. 
## Feel free to adjust your log scaling per your preference. 

view_freq = pd.read_csv('frequency-csvs/l3_alu_b_cells.csv')
view_freq
# Out:
#            sample.visitDetails         manual.label_l3  count  total_count  \
# 0    MM End Induction 1st Draw           b_memory_cd95    188         5003
# 1    MM End Induction 1st Draw           b_memory_core    401         5003
# 2    MM End Induction 1st Draw       b_memory_effector     63         5003
# 3    MM End Induction 1st Draw                 b_naive   2478         5003
# 4    MM End Induction 1st Draw         b_naive_isg_pos     35         5003
# 5    MM End Induction 1st Draw          b_transitional   1115         5003
# 6    MM End Induction 1st Draw  b_transitional_isg_pos     62         5003
# 7    MM End Induction 1st Draw    prog_b_proliferating    661         5003
# 8    MM Post Transplant 1 year           b_memory_cd95    129         8743
# 9    MM Post Transplant 1 year           b_memory_core    212         8743
# 10   MM Post Transplant 1 year       b_memory_effector     40         8743
# 11   MM Post Transplant 1 year                 b_naive   4366         8743
# 12   MM Post Transplant 1 year       b_naive_activated      1         8743
# 13   MM Post Transplant 1 year         b_naive_isg_pos     67         8743
# 14   MM Post Transplant 1 year          b_transitional   2853         8743
# 15   MM Post Transplant 1 year  b_transitional_isg_pos    152         8743
# 16   MM Post Transplant 1 year    prog_b_proliferating    923         8743
# 17   MM Post Transplant 2 year           b_memory_cd95     85        10978
# 18   MM Post Transplant 2 year           b_memory_core    261        10978
# 19   MM Post Transplant 2 year       b_memory_effector     35        10978
# 20   MM Post Transplant 2 year                 b_naive   4346        10978
# 21   MM Post Transplant 2 year         b_naive_isg_pos     54        10978
# 22   MM Post Transplant 2 year          b_transitional   4029        10978
# 23   MM Post Transplant 2 year  b_transitional_isg_pos    144        10978
# 24   MM Post Transplant 2 year    prog_b_proliferating   2024        10978
# 25  MM Post Transplant 90 Days           b_memory_cd95     94        19882
# 26  MM Post Transplant 90 Days           b_memory_core    331        19882
# 27  MM Post Transplant 90 Days       b_memory_effector    153        19882
# 28  MM Post Transplant 90 Days                 b_naive   8078        19882
# 29  MM Post Transplant 90 Days       b_naive_activated      3        19882
# 30  MM Post Transplant 90 Days         b_naive_isg_pos    402        19882
# 31  MM Post Transplant 90 Days          b_transitional   7478        19882
# 32  MM Post Transplant 90 Days  b_transitional_isg_pos    709        19882
# 33  MM Post Transplant 90 Days    prog_b_proliferating   2634        19882
# 34            MM Pre-Treatment           b_memory_cd95    478        17505
# 35            MM Pre-Treatment           b_memory_core   1811        17505
# 36            MM Pre-Treatment       b_memory_effector    269        17505
# 37            MM Pre-Treatment                 b_naive  10996        17505
# 38            MM Pre-Treatment       b_naive_activated     68        17505
# 39            MM Pre-Treatment         b_naive_isg_pos    584        17505
# 40            MM Pre-Treatment          b_transitional   2208        17505
# 41            MM Pre-Treatment  b_transitional_isg_pos    370        17505
# 42            MM Pre-Treatment    prog_b_proliferating    721        17505
#
#     frequency  normalized_frequency  log_normalized_frequency
# 0    0.037577              0.407966                  0.342146
# 1    0.080152              0.322830                  0.279773
# 2    0.012592              0.290027                  0.254663
# 3    0.495303              0.204247                  0.185855
# 4    0.006996              0.095624                  0.091324
# 5    0.222866              0.157120                  0.145934
# 6    0.012393              0.124308                  0.117168
# 7    0.132121              0.221780                  0.200309
# 8    0.014755              0.160187                  0.148581
# 9    0.024248              0.097664                  0.093184
# 10   0.004575              0.105373                  0.100183
# 11   0.499371              0.205925                  0.187247
# 12   0.000114              0.027562                  0.027189
# 13   0.007663              0.104748                  0.099617
# 14   0.326318              0.230053                  0.207058
# 15   0.017385              0.174390                  0.160749
# 16   0.105570              0.177212                  0.163149
# 17   0.007743              0.084061                  0.080714
# 18   0.023775              0.095758                  0.091447
# 19   0.003188              0.073430                  0.070859
# 20   0.395883              0.163249                  0.151217
# 21   0.004919              0.067236                  0.065072
# 22   0.367007              0.258739                  0.230110
# 23   0.013117              0.131576                  0.123612
# 24   0.184369              0.309484                  0.269633
# 25   0.004728              0.051329                  0.050055
# 26   0.016648              0.067054                  0.064902
# 27   0.007695              0.177239                  0.163172
# 28   0.406297              0.167544                  0.154902
# 29   0.000151              0.036360                  0.035715
# 30   0.020219              0.276374                  0.244023
# 31   0.376119              0.265163                  0.235201
# 32   0.035660              0.357705                  0.305796
# 33   0.132482              0.222386                  0.200804
# 34   0.027306              0.296458                  0.259636
# 35   0.103456              0.416693                  0.348325
# 36   0.015367              0.353931                  0.303012
# 37   0.628163              0.259035                  0.230345
# 38   0.003885              0.936078                  0.660664
# 39   0.033362              0.456018                  0.375705
# 40   0.126135              0.088925                  0.085191
# 41   0.021137              0.212021                  0.192289
# 42   0.041188              0.069139                  0.066854
